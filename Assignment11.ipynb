# %% [markdown]
# <a href="https://colab.research.google.com/github/Abyad-Raiyan/projects/blob/main/Assignment11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
df=pd.read_csv("canada_per_capita_income.csv")
print(df)
year=df.drop("per capita income (US$)",axis=1)
income=df["per capita income (US$)"]
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
x=df[["year"]]
y=df["per capita income (US$)"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(f"Training set size: {len(x_train)} samples")
print(f"Testing set size: {len(x_test)} samples")
print("\n" + "="*50 + "\n")
# Out:
# Training set size: 37 samples
# Testing set size: 10 samples
#
# ...

# %%
model=LinearRegression()
model.fit(x_train,y_train)
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)
print("Model Parameters:")
print(f"Intercept: {model.intercept_:.2f}")
print(f"Coefficient (slope): {model.coef_[0]:.2f}")
print(f"Formula: Income = {model.coef_[0]:.2f} * Year + ({model.intercept_:.2f})")
print("\n" + "="*50 + "\n")
print("Model Performance Metrics:")
train_r2 = r2_score(y_train, y_pred_train)
train_rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
train_mae = mean_absolute_error(y_train, y_pred_train)
print("\nTraining Set:")
print(f"R² Score: {train_r2:.4f}")
print(f"RMSE: ${train_rmse:.2f}")
print(f"MAE: ${train_mae:.2f}")
# Out:
# Model Parameters:
# Intercept: -1605560.20
# Coefficient (slope): 815.14
# Formula: Income = 815.14 * Year + (-1605560.20)
#
# ...
#
# Model Performance Metrics:
#
# Training Set:
# R² Score: 0.8934
# RMSE: $3949.90
# MAE: $3002.35

# %%
test_r2 = r2_score(y_test, y_pred_test)
test_rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
test_mae = mean_absolute_error(y_test, y_pred_test)

print("\nTesting Set:")
print(f"R² Score: {test_r2:.4f}")
print(f"RMSE: ${test_rmse:.2f}")
print(f"MAE: ${test_mae:.2f}")
print("\n" + "="*50 + "\n")
# Out:
# Testing Set:
# R² Score: 0.8752
# RMSE: $3892.02
# MAE: $3240.91
#
# ...

# %%
print(model.predict([[2020]]))
# Out:
# [41288.69409442]
